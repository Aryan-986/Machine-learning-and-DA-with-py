# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryan-986/Machine-learning-and-DA-with-py/blob/main/6.%20Handling%20Imbalanced%20Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Imbalance Dataset

# %% [markdown]
# A dataset with an unequal class distribution

# %%
#importing the dependencies
import numpy as np
import pandas as pd

# %%
#loading the datasets to pandas Dataframe

# %%
credit_card_data = pd.read_csv('/content/credit_data.csv')

# %%
#first five rows of the dataframe
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 89215  62476 -0.815634 -0.244177  2.591455 -0.002720 -0.644497  0.418909
# 89216  62476  1.121527  0.208353  0.202133  1.138648  0.068794 -0.158828
# 89217  62478 -1.344549  0.543027  1.991882 -1.118447 -0.949264  0.196963
# 89218  62480  0.789027 -1.180048 -0.633627 -0.141463 -0.317314 -0.124994
# 89219  62480  1.244599 -0.778287 -0.340844 -0.695168 -0.480820 -0.200516
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 89215  0.255767  0.115134  0.649661  ... -0.133162 -0.239654  0.095507
# 89216  0.176503 -0.105339 -0.145071  ...  0.115269  0.354326 -0.179000
# 89217 -0.070728  0.809195  0.331360  ... -0.134573 -0.417982 -0.071393
# 89218  0.407588 -0.286734 -1.371513  ... -0.567100 -1.844598 -0.140709
# 89219 -0.195502 -0.139240       NaN  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
#distribution of the two classes
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    89008
# 1.0      211
# Name: count, dtype: int64

# %% [markdown]
# This is highly imbalanced database

# %% [markdown]
# *   Legit Transaction -----> 0
# *   Fraudulent Transaction -----> 1

# %%
#seperating the legit and fraudulent transactions

# %%
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (89008, 31)
# (211, 31)

# %% [markdown]
# Undersampling

# %% [markdown]
# Build a sample dataset containing similar distribution of legit and fraudulent transactions

# %% [markdown]
# Number Fraudlant transaction ---> 492

# %%
legit_sample = legit.sample(n=492)

# %%
print(legit_sample.shape)
# Out:
# (492, 31)

# %% [markdown]
# Concatnete the two Data frames

# %%
new_dataset = pd.concat([legit_sample, fraud], axis =0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 3617    3093  0.986391 -0.711393  1.031473  0.259056 -1.341535 -0.416234
# 87361  61650  1.076375  0.148377  1.000840  1.467166 -0.513751 -0.129168
# 60693  49451 -0.117841  0.392402  0.999877 -0.831140 -0.555012 -1.063975
# 17482  28758 -0.901804  0.182260  1.337870 -0.589233  1.179772 -1.071955
# 32851  36989 -0.264969  0.371927  1.154290 -0.731706 -0.173634 -0.385582
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 3617  -0.531465  0.011421  1.075433  ... -0.045849 -0.209549 -0.045508
# 87361 -0.121397  0.025820  0.318293  ... -0.269279 -0.579988  0.153284
# 60693  0.343171 -0.248752 -1.456250  ... -0.314370 -0.504158 -0.013244
# 17482  0.871792 -0.170738 -0.626508  ... -0.278413 -1.045063  0.011874
# 32851  0.220313 -0.283213 -0.953101  ...  0.044752  0.298452 -0.091955
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 88258  62059 -1.644403  3.129852 -2.576977  3.415573 -0.448525 -1.241893
# 88307  62080 -1.599457  2.607720 -2.987193  3.064156 -2.497914 -0.541103
# 88876  62330  1.140865  1.221317 -1.452955  2.067575  0.854742 -0.981223
# 88897  62341 -5.267760  2.506719 -5.290925  4.886134 -3.343188 -1.100085
# 89190  62467 -5.344665 -0.285760 -3.835616  5.337048 -7.609909  3.874668
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 88258 -1.991652  1.002665 -2.809071  ...  0.417762 -0.648576 -0.318617
# 88307 -2.277786  1.268166 -1.997331  ...  0.662933  0.184087 -0.089452
# 88876  0.325714 -0.037721  0.113219  ... -0.377597 -0.793460 -0.132333
# 88897 -5.810509  1.726343 -0.749277  ...  0.764266  0.473262  0.548482
# 89190  1.289630  0.201742 -3.003532  ...  0.276011  1.342045 -1.016579
#
#             V24       V25       V26       V27       V28   Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0    211
# Name: count, dtype: int64
